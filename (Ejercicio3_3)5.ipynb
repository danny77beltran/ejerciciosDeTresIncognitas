# %% [markdown]
# <a href="https://colab.research.google.com/github/danny77beltran/ejerciciosDeTresIncognitas/blob/main/(Ejercicio3_3)5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime
from sympy import symbols, Eq, solve
import pytz

# Definir la zona horaria de Ecuador
ecuador_tz = pytz.timezone("America/Guayaquil")
# Obtener la hora actual de Ecuador
hora_actual = datetime.now(ecuador_tz)
# Imprimir la hora en formato legible

print("Hora actual en Ecuador:", hora_actual.strftime("%Y-%m-%d %H:%M:%S"))
print("Danny Fernando Beltrán")
print("Primer ciclo - computación")


x, y, z = symbols('x y z')
sol = solve([
    Eq(x + 2*y - z, 7),
    Eq(x - y + 2*z, -5),
    Eq(-3*x + y  + 4*z, -17)
], (x, y, z))
sol
# Out:
# Hora actual en Ecuador: 2025-10-20 21:44:24
# Danny Fernando Beltrán
# Primer ciclo - computación
# {x: 2, y: 1, z: -3}
